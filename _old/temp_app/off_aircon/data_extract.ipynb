# %% [markdown]
# 데이터 정제 - no 에어컨 환경
# 1. 없음
# 2. 사람 1
# 3. 사람 2
# 4. 히터 1

# %%
import pandas as pd
import os

# %%
csvlist = [x for x in os.listdir('.') if x.endswith('.csv')]
print(csvlist)
# Out:
# ['thermal_data_heater.csv', 'thermal_data_human_one.csv', 'thermal_data_human_two.csv', 'thermal_data_none.csv']

# %%
hedf = pd.DataFrame(pd.read_csv(f'./{csvlist[0]}', index_col=1, header=0))
hudf = pd.DataFrame(pd.read_csv(f'./{csvlist[1]}', index_col=1, header=0))
hsdf = pd.DataFrame(pd.read_csv(f'./{csvlist[2]}', index_col=1, header=0))
nodf = pd.DataFrame(pd.read_csv(f'./{csvlist[3]}', index_col=1, header=0))
dflist = [hedf, hudf, hsdf, nodf]
stlist = ['heater', 'human1', 'human2', 'None']
for x, y in zip(dflist, stlist):
    x['staus'] = y
for x in dflist:
    print(x['staus'].head())
# Out:
# packet_id
# 177    heater
# 178    heater
# 179    heater
# 180    heater
# 181    heater
# Name: staus, dtype: object
# packet_id
# 11    human1
# 12    human1
# 13    human1
# 14    human1
# 15    human1
# Name: staus, dtype: object
# packet_id
# 26    human2
# 27    human2
# 28    human2
# 29    human2
# 30    human2
# Name: staus, dtype: object
# packet_id
# 1    None
# 2    None
# 3    None
# 4    None
# 5    None
# Name: staus, dtype: object

# %%
interDF = pd.concat((dflist[0], dflist[1], dflist[2], dflist[3]), join='outer')

interDF['staus'].unique()
interDF.reset_index(drop=True, inplace=True)

# %%
interDF.index.unique()
# Out:
# RangeIndex(start=0, stop=10002, step=1)

# %%
interDF.head()
# Out:
#              timestamp  sensor_degree  thermal_00  thermal_01  thermal_02  \
# 0  2025-07-29 14:29:00        29.9375       25.75       25.25       25.25
# 1  2025-07-29 14:29:00        29.9375       25.00       24.75       24.75
# 2  2025-07-29 14:29:00        29.9375       25.25       25.25       25.50
# 3  2025-07-29 14:29:01        30.0000       26.00       25.75       25.25
# 4  2025-07-29 14:29:01        29.9375       26.25       25.75       25.50
#
#    thermal_03  thermal_04  thermal_05  thermal_06  thermal_07  ...  \
# 0       25.75       25.75       24.50       24.75       24.75  ...
# 1       25.50       25.00       25.00       24.75       26.25  ...
# 2       25.75       25.75       25.50       25.75       26.25  ...
# 3       26.00       25.50       25.25       25.75       25.50  ...
# 4       26.00       25.00       25.50       25.75       26.00  ...
#
#    thermal_57  thermal_58  thermal_59  thermal_60  thermal_61  thermal_62  \
# 0       50.75       42.50       25.25       24.75       25.75       23.25
# 1       51.00       42.50       24.50       26.00       25.00       23.00
# 2       51.25       42.75       25.00       25.75       25.00       23.00
# 3       50.75       42.50       25.00       25.75       25.25       23.25
# 4       50.25       42.75       25.25       26.00       25.50       23.00
#
#    thermal_63  etc_1  etc_2   staus
# 0       22.50  242.0  226.0  heater
# 1       22.50  242.0  225.0  heater
# 2       22.25  241.0  225.0  heater
# 3       22.75  242.0  225.0  heater
# 4       22.25  242.0  225.0  heater
#
# [5 rows x 69 columns]

# %%
interDF.to_csv('./total_thermal_noAC.csv', index_label=True)
